# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(os.listdir("/kaggle/input/feedback-prize-2021"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-fb55af402aaa> in <module>
# ----> 1 print(os.listdir("/kaggle/input/feedback-prize-2021"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/feedback-prize-2021'

# %%
train = pd.read_csv("/kaggle/input/feedback-prize-2021/train.csv")
train.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1f08f61dd6b7> in <module>
# ----> 1 train = pd.read_csv("/kaggle/input/feedback-prize-2021/train.csv")
#       2 train.head(10)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
print('Number of unique ID: ', len(train['id'].unique()))
print('Number of unique discourse ID: ', len(train['discourse_id'].unique()))

# %%
for i, v in enumerate(train['discourse_type'].value_counts()):
    print(v)

# %%
train['discourse_type'].value_counts().sort_values(ascending=True).plot(kind='barh', width=0.8, figsize=(8,8))
plt.tick_params(right=False, labelright=False)
plt.box(False)
ylocs, ylabs = plt.xticks()
for i, v in enumerate(train['discourse_type'].value_counts().sort_values(ascending=True)):
    if i == 0:
        plt.text(v - 4000, i, str(v), color='white', weight='bold', fontsize=11)
    elif i == 1:
        plt.text(v - 4600, i, str(v), color='white', weight='bold', fontsize=11)
    else:
        plt.text(v - 6000, i, str(v), color='white', weight='bold', fontsize=11)
plt.yticks(fontsize=16, rotation=0)
plt.tight_layout()

plt.show()

# %%
document_id = train['id'].unique()[0]

# %%
train[train['id'] == document_id]

# %%
document_id = train['id'].unique()[1]
document_df = train[train['id'] == document_id]


with open(os.path.join('/kaggle/input/feedback-prize-2021/train', document_id + '.txt')) as f:
    content = f.read()
f.close()

highlighted_text = []

color_dict = {
    'Lead': 'rgb(252, 151, 144)',
    'Position': 'rgb(253, 255, 143)', 
    'Evidence': 'rgb(164, 250, 132)', 
    'Claim': 'rgb(126, 237, 233)', 
    'Concluding Statement': 'rgb(150, 206, 255)',
    'Counterclaim': 'rgb(255, 120, 163)', 
    'Rebuttal':'rgb(247, 109, 111)'
}

for i, word in enumerate(content.split()):
    
    for j, prediction_string in enumerate(document_df.iloc[:, 7]):
        prediction_string = [int(k) for k in prediction_string.split(' ')]
        if i in prediction_string:
            highlighted_text.append('<span style="background-color:' + color_dict[document_df.iloc[j,5]] + ';">' + word + '</span>')  
        
        if j == len(document_df.iloc[:, 7]):
            highlighted_text.append(word)
            
            
        
            
   
        
highlighted_text = ' '.join(highlighted_text)

display(HTML(highlighted_text))

legend_html = []
for category in train.iloc[:, 5].unique():
    legend_html.append('<span style="background-color:' + color_dict[category] + ';"><b>' + category + '</b></span>')
    
print('\n\n')

display(HTML(' '.join(legend_html)))
